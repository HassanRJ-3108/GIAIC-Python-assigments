# %%
import random  # Import random module for number generation

# Constant: Number of rounds
NUM_ROUNDS = 5  

def main():
    print("Welcome to the High-Low Game!")  
    print('--------------------------------')

    score = 0  # Initialize player score

    # Loop for multiple rounds
    for round_num in range(1, NUM_ROUNDS + 1):
        print(f"Round {round_num}")  # Display round number

        # Generate random numbers for player and computer (1 to 100)
        player_number = random.randint(1, 100)
        computer_number = random.randint(1, 100)

        print(f"Your number is {player_number}")  # Show player's number

        # Get user input for guess: "higher" or "lower"
        guess = input("Do you think your number is higher or lower than the computer's? (Enter 'higher' or 'lower'): ").strip().lower()

        # Validate user input
        while guess not in ["higher", "lower"]:
            guess = input("Invalid input! Please enter either 'higher' or 'lower': ").strip().lower()

        # Game logic: Check if the player's guess is correct
        if (guess == "higher" and player_number > computer_number) or (guess == "lower" and player_number < computer_number):
            print(f"You were right! The computer's number was {computer_number}")  
            score += 1  # Increase score if the guess was correct
        else:
            print(f"Aww, that's incorrect. The computer's number was {computer_number}")

        # Display the player's score after each round
        print(f"Your score is now {score}\n")

    # Game over - Display final messages based on performance
    print("Thanks for playing!")

    # Conditional ending messages based on performance
    if score == NUM_ROUNDS:
        print(f"Wow! You played perfectly! 🎯🏆 \nYour score is: {score}")
    elif score >= NUM_ROUNDS // 2:
        print(f"Good job, you played really well! 👍\nYour Score is: {score}")
    else:
        print(f"Better luck next time! 😊 \nYour score is: {score}")

# Run the game
if __name__ == "__main__":
    main()
# Out:
# Welcome to the High-Low Game!
# --------------------------------
# Round 1
# Your number is 34
# Aww, that's incorrect. The computer's number was 29
# Your score is now 0
#
# Round 2
# Your number is 81
# You were right! The computer's number was 41
# Your score is now 1
#
# Round 3
# Your number is 100
# You were right! The computer's number was 10
# Your score is now 2
#
# Round 4
# Your number is 45
# Aww, that's incorrect. The computer's number was 20
# Your score is now 2
#
# Round 5
# Your number is 35
# Aww, that's incorrect. The computer's number was 2
# Your score is now 2
#
# Your final score is 2
# Better luck next time!
